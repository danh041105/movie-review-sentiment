# %%
import pandas as pd

# %%
df = pd.read_parquet("part-00000-1dc04697-6f9c-4bbf-9ce6-ea83b4559eb2-c000.snappy.parquet")

df.head(5)
# Out:
#                            ingestion_id source_system  \
# 0  253d5104-0383-4e86-bc19-6cc2c3011449          tmdb
#
#          ingestion_timestamp  \
# 0 2026-04-06 01:06:51.728934
#
#                                             raw_hash  tmdb_id     imdb_id  \
# 0  df35360b3ecd5e9c1a74c3ae2bd6b058ceb7ca70d9dc3c...  1208348  tt14142060
#
#            title original_title           genres original_language  \
# 0  Rental Family  Rental Family  [Drama, Comedy]                en
#
#   release_date  duration_seconds  tmdb_vote_average  tmdb_vote_count  \
# 0   2025-11-20              6600               7.77              669
#
#                                             overview
# 0  An American actor in Tokyo struggles to find p...
